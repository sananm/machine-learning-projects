# %%
import pandas as pd

# %%
df=pd.read_html('http://lib.stat.cmu.edu/datasets/boston')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\moham\Documents\Python programs\machine-learning-projects\Housing prediction\main.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/moham/Documents/Python%20programs/machine-learning-projects/Housing%20prediction/main.ipynb#ch0000003?line=0'>1</a> df=pd.read_html('http://lib.stat.cmu.edu/datasets/boston')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///~/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...
